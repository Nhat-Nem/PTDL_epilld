# %% [markdown]
# <a href="https://colab.research.google.com/github/Nhat-Nem/PTDL_epilld/blob/master/ePillID_tutorial_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ePillID-benchmark
#
# * https://github.com/usuyama/ePillID-benchmark
# * https://arxiv.org/abs/2005.14288
#
#
# ```
# @inproceedings{usuyama2020epillid,
#   title={ePillID Dataset: A Low-Shot Fine-Grained Benchmark for Pill Identification},
#   author={Usuyama, Naoto and Delgado, Natalia Larios and Hall, Amanda K and Lundin, Jessica},
#   booktitle={Proceedings of the IEEE Conference on Computer Vision and Pattern Recognition Workshops},
#   year={2020}
# }
# ```

# %%
import os

if not os.path.exists("PTDL_epilld"):
  # !git clone https://github.com/Nhat-Nem/PTDL_epilld
# Out:
# fatal: destination path 'PTDL_epilld' already exists and is not an empty directory.

# %% [markdown]
# ## Download the data and unzip

# %%
if not os.path.exists("ePillID_data.zip"):
  # !curl -L -o ePillID_data.zip "https://github.com/usuyama/ePillID-benchmark/releases/download/ePillID_data_v1.0/ePillID_data.zip"

# %%
if not os.path.exists("ePillID_data"):
  # !unzip ePillID_data.zip
# Out:
# Archive:  ePillID_data.zip
#   End-of-central-directory signature not found.  Either this file is not
#   a zipfile, or it constitutes one disk of a multi-part archive.  In the
#   latter case the central directory and zipfile comment will be found on
#   the last disk(s) of this archive.
# unzip:  cannot find zipfile directory in one of ePillID_data.zip or
#         ePillID_data.zip.zip, and cannot find ePillID_data.zip.ZIP, period.

# %%
if not os.path.exists("train_cv.py"):
  # %cd ePillID-benchmark/src

# !echo `pwd`
# !ls
# Out:
# /content/ePillID-benchmark/src
# /content/ePillID-benchmark/src
# arguments.py	       metrics.py	    multihead_trainer.py  train_nocv.py
# classif_utils.py       metric_test_eval.py  pillid_datasets.py
# configs		       metric_utils.py	    sanitytest_eval.py
# image_augmentators.py  models		    train_cv.py

# %% [markdown]
# ## Enabling GPU on Colab
#
# Need to enable GPU from Notebook settings
#
# - Navigate to Edit-Notebook settings menu
# - Select GPU from the Hardware Accelerator dropdown list

# %%
import torch

if not torch.cuda.is_available():
  raise Exception("GPU not availalbe. CPU training will be too slow.")

print("device name", torch.cuda.get_device_name(0))
# Out:
# device name Tesla P100-PCIE-16GB

# %% [markdown]
# ## Install dependencies
#
# The library versions on Colab might be different from what we used in our experiments. Check our repo for full dependencies
#  https://github.com/usuyama/ePillID-benchmark/tree/master/docker

# %%
# !pip install azureml-sdk
# Out:
# Collecting azureml-sdk
#   Downloading https://files.pythonhosted.org/packages/14/e1/f91d7b2c5ec5c8c0374db4b95006a3e2911b5ef6991138149bb7d7a4a3ec/azureml_sdk-1.9.0-py3-none-any.whl
# Collecting azureml-train~=1.9.0
#   Downloading https://files.pythonhosted.org/packages/c4/16/ede281a41fedffee6dd055621ca8a894055a5934284fcefb93e9cb324cbd/azureml_train-1.9.0-py3-none-any.whl
# Collecting azureml-core~=1.9.0
#   Downloading https://files.pythonhosted.org/packages/1d/58/e74e76d130cf1d65271f08475ac7ce9adfc01da89a018a6d88775131c3de/azureml_core-1.9.0-py3-none-any.whl (1.5MB)
#      |████████████████████████████████| 1.5MB 8.4MB/s
# Collecting azureml-train-automl-client~=1.9.0
#   Downloading https://files.pythonhosted.org/packages/f3/08/9cf39d90d20e33d67412f942412586fbb659bf5dd34668b6e9352f8cc609/azureml_train_automl_client-1.9.0-py3-none-any.whl (92kB)
#      |████████████████████████████████| 102kB 13.3MB/s
# Collecting azureml-dataprep[fuse]<1.10.0a,>=1.9.0a
#   Downloading https://files.pythonhosted.org/packages/d7/4e/13953bb6fd454644cb6c45bcff8c326332660ac408392ef2cb6d510c8a70/azureml_dataprep-1.9.1-py3-none-any.whl (27.7MB)
#      |████████████████████████████████| 27.7MB 83kB/s
# Collecting azureml-pipeline~=1.9.0
#   Downloading https://files.pythonhosted.org/packages/d3/e2/8aa9db8b15a383e16b30170ead963fccc9422d918d031caad74bd6bdb4c6/azureml_pipeline-1.9.0-py3-none-any.whl
# Collecting azureml-train-core~=1.9.0
#   Downloading https://files.pythonhosted.org/packages/49/ca/4017fd0fd2f4a440cfac7b6f2464e6eee48d0e363318f08b177f49acc195/azureml_train_core-1.9.0-py3-none-any.whl (8.6MB)
#      |████████████████████████████████| 8.6MB 53.4MB/s
# Collecting azure-common>=1.1.12
#   Downloading https://files.pythonhosted.org/packages/e5/4d/d000fc3c5af601d00d55750b71da5c231fcb128f42ac95b208ed1091c2c1/azure_common-1.1.25-py2.py3-none-any.whl
# Collecting jsonpickle
#   Downloading https://files.pythonhosted.org/packages/af/ca/4fee219cc4113a5635e348ad951cf8a2e47fed2e3342312493f5b73d0007/jsonpickle-1.4.1-py2.py3-none-any.whl
# Collecting azure-mgmt-authorization>=0.40.0
#   Downloading https://files.pythonhosted.org/packages/5e/17/4724694ddb3311955ddc367eddcd0928f8ee2c7b12d5a6f0b12bca0b03db/azure_mgmt_authorization-0.60.0-py2.py3-none-any.whl (82kB)
#      |████████████████████████████████| 92kB 11.9MB/s
# Collecting azure-graphrbac>=0.40.0
#   Downloading https://files.pythonhosted.org/packages/3e/93/02056aca45162f9fc275d1eaad12a2a07ef92375afb48eabddc4134b8315/azure_graphrbac-0.61.1-py2.py3-none-any.whl (141kB)
#      |████████████████████████████████| 143kB 61.9MB/s
# Collecting SecretStorage
#   Downloading https://files.pythonhosted.org/packages/c3/50/8a02cad020e949e6d7105f5f4530d41e3febcaa5b73f8f2148aacb3aeba5/SecretStorage-3.1.2-py3-none-any.whl
# Collecting backports.tempfile
#   Downloading https://files.pythonhosted.org/packages/b4/5c/077f910632476281428fe254807952eb47ca78e720d059a46178c541e669/backports.tempfile-1.0-py2.py3-none-any.whl
# Collecting msrest>=0.5.1
#   Downloading https://files.pythonhosted.org/packages/b6/b4/a95380d5199c4785b318038db6d199a203f6970188876b473c00533bc17f/msrest-0.6.17-py2.py3-none-any.whl (84kB)
#      |████████████████████████████████| 92kB 11.2MB/s
# Requirement already satisfied: pytz in /usr/local/lib/python3.6/dist-packages (from azureml-core~=1.9.0->azureml-sdk) (2018.9)
# Collecting cryptography!=1.9,!=2.0.*,!=2.1.*,!=2.2.*
#   Downloading https://files.pythonhosted.org/packages/3c/04/686efee2dcdd25aecf357992e7d9362f443eb182ecd623f882bc9f7a6bba/cryptography-2.9.2-cp35-abi3-manylinux2010_x86_64.whl (2.7MB)
#      |████████████████████████████████| 2.7MB 48.5MB/s
# Collecting azure-mgmt-resource>=1.2.1
#   Downloading https://files.pythonhosted.org/packages/36/81/1d108d908c526c70c79a1b8ec833d09e6d5e0619282516f510840eb97c5d/azure_mgmt_resource-10.1.0-py2.py3-none-any.whl (892kB)
#      |████████████████████████████████| 901kB 48.7MB/s
# Collecting pyopenssl
#   Downloading https://files.pythonhosted.org/packages/9e/de/f8342b68fa9e981d348039954657bdf681b2ab93de27443be51865ffa310/pyOpenSSL-19.1.0-py2.py3-none-any.whl (53kB)
#      |████████████████████████████████| 61kB 9.2MB/s
# Collecting docker
#   Downloading https://files.pythonhosted.org/packages/3c/15/7a2f095a3b8b0fff9a0a5f56bd941e05fa958d4ca31105541001a5f7d3eb/docker-4.2.2-py2.py3-none-any.whl (144kB)
#      |████████████████████████████████| 153kB 57.9MB/s
# Requirement already satisfied: urllib3>=1.23 in /usr/local/lib/python3.6/dist-packages (from azureml-core~=1.9.0->azureml-sdk) (1.24.3)
# Requirement already satisfied: requests>=2.19.1 in /usr/local/lib/python3.6/dist-packages (from azureml-core~=1.9.0->azureml-sdk) (2.23.0)
# Collecting azure-mgmt-containerregistry>=2.0.0
#   Downloading https://files.pythonhosted.org/packages/97/70/8c2d0509db466678eba16fa2b0a539499f3b351b1f2993126ad843d5be13/azure_mgmt_containerregistry-2.8.0-py2.py3-none-any.whl (718kB)
#      |████████████████████████████████| 727kB 52.3MB/s
# Collecting ndg-httpsclient
#   Downloading https://files.pythonhosted.org/packages/fb/67/c2f508c00ed2a6911541494504b7cac16fe0b0473912568df65fd1801132/ndg_httpsclient-0.5.1-py3-none-any.whl
# Collecting azure-mgmt-storage>=1.5.0
#   Downloading https://files.pythonhosted.org/packages/60/6c/2f170614e3414e807c8f18a197237a0a54c3cebf770e4cb3b2ef31138f58/azure_mgmt_storage-11.1.0-py2.py3-none-any.whl (547kB)
#      |████████████████████████████████| 552kB 50.6MB/s
# Collecting pathspec
#   Downloading https://files.pythonhosted.org/packages/5d/d0/887c58853bd4b6ffc7aa9cdba4fc57d7b979b45888a6bd47e4568e1cf868/pathspec-0.8.0-py2.py3-none-any.whl
# Collecting azure-mgmt-network~=10.0
#   Downloading https://files.pythonhosted.org/packages/39/d8/84a181e6e4926ebad56e68c1d05427f5ad64e7a784acab82a302dc4a93d2/azure_mgmt_network-10.2.0-py2.py3-none-any.whl (8.6MB)
#      |████████████████████████████████| 8.6MB 162kB/s
# Collecting ruamel.yaml>0.16.7
#   Downloading https://files.pythonhosted.org/packages/a6/92/59af3e38227b9cc14520bf1e59516d99ceca53e3b8448094248171e9432b/ruamel.yaml-0.16.10-py2.py3-none-any.whl (111kB)
#      |████████████████████████████████| 112kB 55.9MB/s
# Collecting azure-mgmt-keyvault>=0.40.0
#   Downloading https://files.pythonhosted.org/packages/f1/af/1ba15e7176bcf6b1531b453e410ae41a983c09f834d8700dfce739451b53/azure_mgmt_keyvault-2.2.0-py2.py3-none-any.whl (89kB)
#      |████████████████████████████████| 92kB 12.3MB/s
# Requirement already satisfied: contextlib2 in /usr/local/lib/python3.6/dist-packages (from azureml-core~=1.9.0->azureml-sdk) (0.5.5)
# Collecting PyJWT
#   Downloading https://files.pythonhosted.org/packages/87/8b/6a9f14b5f781697e51259d81657e6048fd31a113229cf346880bb7545565/PyJWT-1.7.1-py2.py3-none-any.whl
# Collecting msrestazure>=0.4.33
#   Downloading https://files.pythonhosted.org/packages/5e/3a/7adb08fd2f0ee6fdfd03685fac38477b64f184943dcf6ea0cbffb205f22d/msrestazure-0.6.4-py2.py3-none-any.whl (40kB)
#      |████████████████████████████████| 40kB 6.6MB/s
# Collecting adal>=1.2.0
#   Downloading https://files.pythonhosted.org/packages/46/58/a19e0eb0c388fb7aced40f940c09069343862613d83095b592a8d3961ba1/adal-1.2.4-py2.py3-none-any.whl (55kB)
#      |████████████████████████████████| 61kB 9.9MB/s
# Requirement already satisfied: jmespath in /usr/local/lib/python3.6/dist-packages (from azureml-core~=1.9.0->azureml-sdk) (0.10.0)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.6/dist-packages (from azureml-core~=1.9.0->azureml-sdk) (2.8.1)
# Collecting azureml-automl-core~=1.9.0
#   Downloading https://files.pythonhosted.org/packages/6f/fd/3c0ab52cf32c55e9513e407fe3badb5d5bd1e2199b16124c1c8dfb1f6b05/azureml_automl_core-1.9.0-py3-none-any.whl (140kB)
#      |████████████████████████████████| 143kB 41.1MB/s
# Collecting azureml-telemetry~=1.9.0
#   Downloading https://files.pythonhosted.org/packages/bb/82/a0689e1e249a999990e0264db4e3f206bacbb7550c695b24180a7c0073ed/azureml_telemetry-1.9.0-py3-none-any.whl
# Collecting dotnetcore2>=2.1.14
#   Downloading https://files.pythonhosted.org/packages/f8/63/00dcafe16dff60e87b6fedf3e02e13b44fbdcccc3ccbf0215dea4527d59d/dotnetcore2-2.1.14-py3-none-manylinux1_x86_64.whl (29.3MB)
#      |████████████████████████████████| 29.3MB 76kB/s
# Collecting azureml-dataprep-native<15.0.0,>=14.2.1
#   Downloading https://files.pythonhosted.org/packages/3d/5f/294321d87379723f391045c7c866f2d268a3f354a6217f8be890ff999671/azureml_dataprep_native-14.2.1-cp36-cp36m-manylinux1_x86_64.whl (1.3MB)
#      |████████████████████████████████| 1.3MB 61.8MB/s
# Requirement already satisfied: cloudpickle>=1.1.0 in /usr/local/lib/python3.6/dist-packages (from azureml-dataprep[fuse]<1.10.0a,>=1.9.0a->azureml-sdk) (1.3.0)
# Collecting azure-identity<1.3.0,>=1.2.0
#   Downloading https://files.pythonhosted.org/packages/c4/7a/9372cd51fc3408ede0fab950ef9a6518cad34ef36e199982bb1ddfa18512/azure_identity-1.2.0-py2.py3-none-any.whl (58kB)
#      |████████████████████████████████| 61kB 7.6MB/s
# Collecting fusepy>=3.0.1; extra == "fuse"
#   Downloading https://files.pythonhosted.org/packages/04/0b/4506cb2e831cea4b0214d3625430e921faaa05a7fb520458c75a2dbd2152/fusepy-3.0.1.tar.gz
# Collecting azureml-pipeline-steps~=1.9.0
#   Downloading https://files.pythonhosted.org/packages/f8/30/2b18fcdcc4928d510003a6184bc17df3470d98767ce1d66f08ba3184f075/azureml_pipeline_steps-1.9.0-py3-none-any.whl (57kB)
#      |████████████████████████████████| 61kB 8.3MB/s
# Collecting azureml-pipeline-core~=1.9.0
#   Downloading https://files.pythonhosted.org/packages/d2/8c/01c4ea7f976795fc68b98a3d42fa6f30db7c5b079da0931f50d6f3fa3249/azureml_pipeline_core-1.9.0-py3-none-any.whl (290kB)
#      |████████████████████████████████| 296kB 57.0MB/s
# Collecting flake8<=3.7.9,>=3.1.0; python_version >= "3.6"
#   Downloading https://files.pythonhosted.org/packages/f8/1f/7ea40d1e4146ea55dbab41cda1376db092a75794914169aabd7e8d7a7def/flake8-3.7.9-py2.py3-none-any.whl (69kB)
#      |████████████████████████████████| 71kB 9.9MB/s
# Collecting azureml-train-restclients-hyperdrive~=1.9.0
#   Downloading https://files.pythonhosted.org/packages/5f/b7/5677ebd56a8e4867184335dd0b8d5257057a29f637bae5c6a280d72abb7d/azureml_train_restclients_hyperdrive-1.9.0-py3-none-any.whl
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.6/dist-packages (from jsonpickle->azureml-core~=1.9.0->azureml-sdk) (1.6.1)
# Collecting jeepney>=0.4.2
#   Downloading https://files.pythonhosted.org/packages/79/31/2e8d42727595faf224c6dbb748c32b192e212f25495fe841fb7ce8e168b8/jeepney-0.4.3-py3-none-any.whl
# Collecting backports.weakref
#   Downloading https://files.pythonhosted.org/packages/88/ec/f598b633c3d5ffe267aaada57d961c94fdfa183c5c3ebda2b6d151943db6/backports.weakref-1.0.post1-py2.py3-none-any.whl
# Collecting isodate>=0.6.0
#   Downloading https://files.pythonhosted.org/packages/9b/9f/b36f7774ff5ea8e428fdcfc4bb332c39ee5b9362ddd3d40d9516a55221b2/isodate-0.6.0-py2.py3-none-any.whl (45kB)
#      |████████████████████████████████| 51kB 6.9MB/s
# Requirement already satisfied: requests-oauthlib>=0.5.0 in /usr/local/lib/python3.6/dist-packages (from msrest>=0.5.1->azureml-core~=1.9.0->azureml-sdk) (1.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from msrest>=0.5.1->azureml-core~=1.9.0->azureml-sdk) (2020.6.20)
# Requirement already satisfied: cffi!=1.11.3,>=1.8 in /usr/local/lib/python3.6/dist-packages (from cryptography!=1.9,!=2.0.*,!=2.1.*,!=2.2.*->azureml-core~=1.9.0->azureml-sdk) (1.14.0)
# Requirement already satisfied: six>=1.4.1 in /usr/local/lib/python3.6/dist-packages (from cryptography!=1.9,!=2.0.*,!=2.1.*,!=2.2.*->azureml-core~=1.9.0->azureml-sdk) (1.12.0)
# Collecting websocket-client>=0.32.0
#   Downloading https://files.pythonhosted.org/packages/4c/5f/f61b420143ed1c8dc69f9eaec5ff1ac36109d52c80de49d66e0c36c3dfdf/websocket_client-0.57.0-py2.py3-none-any.whl (200kB)
#      |████████████████████████████████| 204kB 61.4MB/s
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests>=2.19.1->azureml-core~=1.9.0->azureml-sdk) (2.9)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests>=2.19.1->azureml-core~=1.9.0->azureml-sdk) (3.0.4)
# Requirement already satisfied: pyasn1>=0.1.1 in /usr/local/lib/python3.6/dist-packages (from ndg-httpsclient->azureml-core~=1.9.0->azureml-sdk) (0.4.8)
# Collecting ruamel.yaml.clib>=0.1.2; platform_python_implementation == "CPython" and python_version < "3.9"
#   Downloading https://files.pythonhosted.org/packages/53/77/4bcd63f362bcb6c8f4f06253c11f9772f64189bf08cf3f40c5ccbda9e561/ruamel.yaml.clib-0.2.0-cp36-cp36m-manylinux1_x86_64.whl (548kB)
#      |████████████████████████████████| 552kB 54.5MB/s
# Collecting applicationinsights
#   Downloading https://files.pythonhosted.org/packages/a1/53/234c53004f71f0717d8acd37876e0b65c121181167057b9ce1b1795f96a0/applicationinsights-0.11.9-py2.py3-none-any.whl (58kB)
#      |████████████████████████████████| 61kB 8.7MB/s
# Collecting distro>=1.2.0
#   Downloading https://files.pythonhosted.org/packages/25/b7/b3c4270a11414cb22c6352ebc7a83aaa3712043be29daa05018fd5a5c956/distro-1.5.0-py2.py3-none-any.whl
# Collecting azure-core<2.0.0,>=1.0.0
#   Downloading https://files.pythonhosted.org/packages/8b/00/efb68e2dda82139d732090fc3b7ff47fe6f34724ea7ba31e518a854b15c1/azure_core-1.7.0-py2.py3-none-any.whl (121kB)
#      |████████████████████████████████| 122kB 64.1MB/s
# Collecting msal<2.0.0,>=1.0.0
#   Downloading https://files.pythonhosted.org/packages/c4/a8/16816334bd2552ebdbb0255518f15698feb94278d92f4f890c38387f1892/msal-1.4.1-py2.py3-none-any.whl (48kB)
#      |████████████████████████████████| 51kB 7.3MB/s
# Collecting msal-extensions~=0.1.3
#   Downloading https://files.pythonhosted.org/packages/21/9b/8bc67822e98573fe0460e30ad0202ab9e0638a42878041c65a6fe857babe/msal_extensions-0.1.3-py2.py3-none-any.whl
# Collecting mccabe<0.7.0,>=0.6.0
#   Downloading https://files.pythonhosted.org/packages/87/89/479dc97e18549e21354893e4ee4ef36db1d237534982482c3681ee6e7b57/mccabe-0.6.1-py2.py3-none-any.whl
# Collecting pycodestyle<2.6.0,>=2.5.0
#   Downloading https://files.pythonhosted.org/packages/0e/0c/04a353e104d2f324f8ee5f4b32012618c1c86dd79e52a433b64fceed511b/pycodestyle-2.5.0-py2.py3-none-any.whl (51kB)
#      |████████████████████████████████| 51kB 7.3MB/s
# Requirement already satisfied: entrypoints<0.4.0,>=0.3.0 in /usr/local/lib/python3.6/dist-packages (from flake8<=3.7.9,>=3.1.0; python_version >= "3.6"->azureml-train-core~=1.9.0->azureml-train~=1.9.0->azureml-sdk) (0.3)
# Collecting pyflakes<2.2.0,>=2.1.0
#   Downloading https://files.pythonhosted.org/packages/84/f2/ed0ffb887f8138a8fe5a621b8c0bb9598bfb3989e029f6c6a85ee66628ee/pyflakes-2.1.1-py2.py3-none-any.whl (59kB)
#      |████████████████████████████████| 61kB 8.7MB/s
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.6/dist-packages (from importlib-metadata->jsonpickle->azureml-core~=1.9.0->azureml-sdk) (3.1.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.6/dist-packages (from requests-oauthlib>=0.5.0->msrest>=0.5.1->azureml-core~=1.9.0->azureml-sdk) (3.1.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.6/dist-packages (from cffi!=1.11.3,>=1.8->cryptography!=1.9,!=2.0.*,!=2.1.*,!=2.2.*->azureml-core~=1.9.0->azureml-sdk) (2.20)
# Collecting portalocker~=1.0
#   Downloading https://files.pythonhosted.org/packages/53/84/7b3146ec6378d28abc73ab484f09f47dfa008ad6f03f33d90a369f880e25/portalocker-1.7.0-py2.py3-none-any.whl
# Building wheels for collected packages: fusepy
#   Building wheel for fusepy (setup.py) ... done
#   Created wheel for fusepy: filename=fusepy-3.0.1-cp36-none-any.whl size=10504 sha256=bda2fecac83200fed97c175451df3642325d0a3149c05529aaf96c3b6a2b4c00
#   Stored in directory: /root/.cache/pip/wheels/4c/a5/91/7772af9e21c461f07bb40f26d928d7d231d224977dd8353bab
# Successfully built fusepy
# Installing collected packages: applicationinsights, azure-common, jsonpickle, isodate, msrest, cryptography, PyJWT, adal, msrestazure, azure-mgmt-authorization, azure-graphrbac, jeepney, SecretStorage, backports.weakref, backports.tempfile, azure-mgmt-resource, pyopenssl, websocket-client, docker, azure-mgmt-containerregistry, ndg-httpsclient, azure-mgmt-storage, pathspec, azure-mgmt-network, ruamel.yaml.clib, ruamel.yaml, azure-mgmt-keyvault, azureml-core, azureml-telemetry, mccabe, pycodestyle, pyflakes, flake8, azureml-train-restclients-hyperdrive, azureml-train-core, azureml-train, distro, dotnetcore2, azureml-dataprep-native, azure-core, msal, portalocker, msal-extensions, azure-identity, fusepy, azureml-dataprep, azureml-automl-core, azureml-train-automl-client, azureml-pipeline-core, azureml-pipeline-steps, azureml-pipeline, azureml-sdk
# Successfully installed PyJWT-1.7.1 SecretStorage-3.1.2 adal-1.2.4 applicationinsights-0.11.9 azure-common-1.1.25 azure-core-1.7.0 azure-graphrbac-0.61.1 azure-identity-1.2.0 azure-mgmt-authorization-0.60.0 azure-mgmt-containerregistry-2.8.0 azure-mgmt-keyvault-2.2.0 azure-mgmt-network-10.2.0 azure-mgmt-resource-10.1.0 azure-mgmt-storage-11.1.0 azureml-automl-core-1.9.0 azureml-core-1.9.0 azureml-dataprep-1.9.1 azureml-dataprep-native-14.2.1 azureml-pipeline-1.9.0 azureml-pipeline-core-1.9.0 azureml-pipeline-steps-1.9.0 azureml-sdk-1.9.0 azureml-telemetry-1.9.0 azureml-train-1.9.0 azureml-train-automl-client-1.9.0 azureml-train-core-1.9.0 azureml-train-restclients-hyperdrive-1.9.0 backports.tempfile-1.0 backports.weakref-1.0.post1 cryptography-2.9.2 distro-1.5.0 docker-4.2.2 dotnetcore2-2.1.14 flake8-3.7.9 fusepy-3.0.1 isodate-0.6.0 jeepney-0.4.3 jsonpickle-1.4.1 mccabe-0.6.1 msal-1.4.1 msal-extensions-0.1.3 msrest-0.6.17 msrestazure-0.6.4 ndg-httpsclient-0.5.1 pathspec-0.8.0 portalocker-1.7.0 pycodestyle-2.5.0 pyflakes-2.1.1 pyopenssl-19.1.0 ruamel.yaml-0.16.10 ruamel.yaml.clib-0.2.0 websocket-client-0.57.0

# %%
# check library versions
# !pip freeze
# Out:
# absl-py==0.9.0
# adal==1.2.4
# alabaster==0.7.12
# albumentations==0.1.12
# altair==4.1.0
# applicationinsights==0.11.9
# asgiref==3.2.10
# astor==0.8.1
# astropy==4.0.1.post1
# astunparse==1.6.3
# atari-py==0.2.6
# atomicwrites==1.4.0
# attrs==19.3.0
# audioread==2.1.8
# autograd==1.3
# azure-common==1.1.25
# azure-core==1.7.0
# azure-graphrbac==0.61.1
# azure-identity==1.2.0
# azure-mgmt-authorization==0.60.0
# azure-mgmt-containerregistry==2.8.0
# azure-mgmt-keyvault==2.2.0
# azure-mgmt-network==10.2.0
# azure-mgmt-resource==10.1.0
# azure-mgmt-storage==11.1.0
# azureml-automl-core==1.9.0
# azureml-core==1.9.0
# azureml-dataprep==1.9.1
# azureml-dataprep-native==14.2.1
# azureml-pipeline==1.9.0
# azureml-pipeline-core==1.9.0
# azureml-pipeline-steps==1.9.0
# azureml-sdk==1.9.0
# azureml-telemetry==1.9.0
# azureml-train==1.9.0
# azureml-train-automl-client==1.9.0
# azureml-train-core==1.9.0
# azureml-train-restclients-hyperdrive==1.9.0
# Babel==2.8.0
# backcall==0.2.0
# backports.tempfile==1.0
# backports.weakref==1.0.post1
# beautifulsoup4==4.6.3
# bleach==3.1.5
# blis==0.4.1
# bokeh==1.4.0
# boto==2.49.0
# boto3==1.14.9
# botocore==1.17.9
# Bottleneck==1.3.2
# branca==0.4.1
# bs4==0.0.1
# CacheControl==0.12.6
# cachetools==4.1.0
# catalogue==1.0.0
# certifi==2020.6.20
# cffi==1.14.0
# chainer==6.5.0
# chardet==3.0.4
# click==7.1.2
# cloudpickle==1.3.0
# cmake==3.12.0
# cmdstanpy==0.4.0
# colorlover==0.3.0
# community==1.0.0b1
# contextlib2==0.5.5
# convertdate==2.2.1
# coverage==3.7.1
# coveralls==0.5
# crcmod==1.7
# cryptography==2.9.2
# cufflinks==0.17.3
# cupy-cuda101==6.5.0
# cvxopt==1.2.5
# cvxpy==1.0.31
# cycler==0.10.0
# cymem==2.0.3
# Cython==0.29.20
# daft==0.0.4
# dask==2.12.0
# dataclasses==0.7
# datascience==0.10.6
# decorator==4.4.2
# defusedxml==0.6.0
# descartes==1.1.0
# dill==0.3.2
# distributed==1.25.3
# distro==1.5.0
# Django==3.0.7
# dlib==19.18.0
# docker==4.2.2
# docopt==0.6.2
# docutils==0.15.2
# dopamine-rl==1.0.5
# dotnetcore2==2.1.14
# earthengine-api==0.1.226
# easydict==1.9
# ecos==2.0.7.post1
# editdistance==0.5.3
# en-core-web-sm==2.2.5
# entrypoints==0.3
# ephem==3.7.7.1
# et-xmlfile==1.0.1
# fa2==0.3.5
# fancyimpute==0.4.3
# fastai==1.0.61
# fastdtw==0.3.4
# fastprogress==0.2.3
# fastrlock==0.5
# fbprophet==0.6
# feather-format==0.4.1
# featuretools==0.4.1
# filelock==3.0.12
# firebase-admin==4.1.0
# fix-yahoo-finance==0.0.22
# flake8==3.7.9
# Flask==1.1.2
# folium==0.8.3
# fsspec==0.7.4
# fusepy==3.0.1
# future==0.16.0
# gast==0.3.3
# GDAL==2.2.2
# gdown==3.6.4
# gensim==3.6.0
# geographiclib==1.50
# geopy==1.17.0
# gin-config==0.3.0
# glob2==0.7
# google==2.0.3
# google-api-core==1.16.0
# google-api-python-client==1.7.12
# google-auth==1.17.2
# google-auth-httplib2==0.0.3
# google-auth-oauthlib==0.4.1
# google-cloud-bigquery==1.21.0
# google-cloud-core==1.0.3
# google-cloud-datastore==1.8.0
# google-cloud-firestore==1.7.0
# google-cloud-language==1.2.0
# google-cloud-storage==1.18.1
# google-cloud-translate==1.5.0
# google-colab==1.0.0
# google-pasta==0.2.0
# google-resumable-media==0.4.1
# googleapis-common-protos==1.52.0
# googledrivedownloader==0.4
# graphviz==0.10.1
# grpcio==1.30.0
# gspread==3.0.1
# gspread-dataframe==3.0.7
# gym==0.17.2
# h5py==2.10.0
# HeapDict==1.0.1
# holidays==0.9.12
# html5lib==1.0.1
# httpimport==0.5.18
# httplib2==0.17.4
# httplib2shim==0.0.3
# humanize==0.5.1
# hyperopt==0.1.2
# ideep4py==2.0.0.post3
# idna==2.9
# image==1.5.32
# imageio==2.4.1
# imagesize==1.2.0
# imbalanced-learn==0.4.3
# imblearn==0.0
# imgaug==0.2.9
# importlib-metadata==1.6.1
# imutils==0.5.3
# inflect==2.1.0
# intel-openmp==2020.0.133
# intervaltree==2.1.0
# ipykernel==4.10.1
# ipython==5.5.0
# ipython-genutils==0.2.0
# ipython-sql==0.3.9
# ipywidgets==7.5.1
# isodate==0.6.0
# itsdangerous==1.1.0
# jax==0.1.69
# jaxlib==0.1.47
# jdcal==1.4.1
# jedi==0.17.1
# jeepney==0.4.3
# jieba==0.42.1
# Jinja2==2.11.2
# jmespath==0.10.0
# joblib==0.15.1
# jpeg4py==0.1.4
# jsonpickle==1.4.1
# jsonschema==2.6.0
# jupyter==1.0.0
# jupyter-client==5.3.4
# jupyter-console==5.2.0
# jupyter-core==4.6.3
# kaggle==1.5.6
# kapre==0.1.3.1
# Keras==2.3.1
# Keras-Applications==1.0.8
# Keras-Preprocessing==1.1.2
# keras-vis==0.4.1
# kiwisolver==1.2.0
# knnimpute==0.1.0
# librosa==0.6.3
# lightgbm==2.2.3
# llvmlite==0.31.0
# lmdb==0.98
# lucid==0.3.8
# LunarCalendar==0.0.9
# lxml==4.2.6
# Markdown==3.2.2
# MarkupSafe==1.1.1
# matplotlib==3.2.2
# matplotlib-venn==0.11.5
# mccabe==0.6.1
# missingno==0.4.2
# mistune==0.8.4
# mizani==0.6.0
# mkl==2019.0
# mlxtend==0.14.0
# more-itertools==8.4.0
# moviepy==0.2.3.5
# mpmath==1.1.0
# msal==1.4.1
# msal-extensions==0.1.3
# msgpack==1.0.0
# msrest==0.6.17
# msrestazure==0.6.4
# multiprocess==0.70.10
# multitasking==0.0.9
# murmurhash==1.0.2
# music21==5.5.0
# natsort==5.5.0
# nbconvert==5.6.1
# nbformat==5.0.7
# ndg-httpsclient==0.5.1
# networkx==2.4
# nibabel==3.0.2
# nltk==3.2.5
# notebook==5.2.2
# np-utils==0.5.12.1
# numba==0.48.0
# numexpr==2.7.1
# numpy==1.18.5
# nvidia-ml-py3==7.352.0
# oauth2client==4.1.3
# oauthlib==3.1.0
# okgrade==0.4.3
# opencv-contrib-python==4.1.2.30
# opencv-python==4.1.2.30
# openpyxl==2.5.9
# opt-einsum==3.2.1
# osqp==0.6.1
# packaging==20.4
# palettable==3.3.0
# pandas==1.0.5
# pandas-datareader==0.8.1
# pandas-gbq==0.11.0
# pandas-profiling==1.4.1
# pandocfilters==1.4.2
# parso==0.7.0
# pathlib==1.0.1
# pathspec==0.8.0
# patsy==0.5.1
# pexpect==4.8.0
# pickleshare==0.7.5
# Pillow==7.0.0
# pip-tools==4.5.1
# plac==1.1.3
# plotly==4.4.1
# plotnine==0.6.0
# pluggy==0.7.1
# portalocker==1.7.0
# portpicker==1.3.1
# prefetch-generator==1.0.1
# preshed==3.0.2
# prettytable==0.7.2
# progressbar2==3.38.0
# prometheus-client==0.8.0
# promise==2.3
# prompt-toolkit==1.0.18
# protobuf==3.10.0
# psutil==5.4.8
# psycopg2==2.7.6.1
# ptyprocess==0.6.0
# py==1.8.2
# pyarrow==0.14.1
# pyasn1==0.4.8
# pyasn1-modules==0.2.8
# pycocotools==2.0.1
# pycodestyle==2.5.0
# pycparser==2.20
# pydata-google-auth==1.1.0
# pydot==1.3.0
# pydot-ng==2.0.0
# pydotplus==2.0.2
# PyDrive==1.3.1
# pyemd==0.5.1
# pyflakes==2.1.1
# pyglet==1.5.0
# Pygments==2.1.3
# pygobject==3.26.1
# PyJWT==1.7.1
# pymc3==3.7
# PyMeeus==0.3.7
# pymongo==3.10.1
# pymystem3==0.2.0
# PyOpenGL==3.1.5
# pyOpenSSL==19.1.0
# pyparsing==2.4.7
# pyrsistent==0.16.0
# pysndfile==1.3.8
# PySocks==1.7.1
# pystan==2.19.1.1
# pytest==3.6.4
# python-apt==1.6.5+ubuntu0.3
# python-chess==0.23.11
# python-dateutil==2.8.1
# python-louvain==0.14
# python-slugify==4.0.0
# python-utils==2.4.0
# pytz==2018.9
# PyWavelets==1.1.1
# PyYAML==3.13
# pyzmq==19.0.1
# qtconsole==4.7.5
# QtPy==1.9.0
# regex==2019.12.20
# requests==2.23.0
# requests-oauthlib==1.3.0
# resampy==0.2.2
# retrying==1.3.3
# rpy2==3.2.7
# rsa==4.6
# ruamel.yaml==0.16.10
# ruamel.yaml.clib==0.2.0
# s3fs==0.4.2
# s3transfer==0.3.3
# scikit-image==0.16.2
# scikit-learn==0.22.2.post1
# scipy==1.4.1
# screen-resolution-extra==0.0.0
# scs==2.1.2
# seaborn==0.10.1
# SecretStorage==3.1.2
# Send2Trash==1.5.0
# setuptools-git==1.2
# Shapely==1.7.0
# simplegeneric==0.8.1
# six==1.12.0
# sklearn==0.0
# sklearn-pandas==1.8.0
# smart-open==2.0.0
# snowballstemmer==2.0.0
# sortedcontainers==2.2.2
# spacy==2.2.4
# Sphinx==1.8.5
# sphinxcontrib-websupport==1.2.2
# SQLAlchemy==1.3.17
# sqlparse==0.3.1
# srsly==1.0.2
# statsmodels==0.10.2
# sympy==1.1.1
# tables==3.4.4
# tabulate==0.8.7
# tbb==2020.0.133
# tblib==1.6.0
# tensorboard==2.2.2
# tensorboard-plugin-wit==1.6.0.post3
# tensorboardcolab==0.0.22
# tensorflow==2.2.0
# tensorflow-addons==0.8.3
# tensorflow-datasets==2.1.0
# tensorflow-estimator==2.2.0
# tensorflow-gcs-config==2.2.0
# tensorflow-hub==0.8.0
# tensorflow-metadata==0.22.2
# tensorflow-privacy==0.2.2
# tensorflow-probability==0.10.0
# termcolor==1.1.0
# terminado==0.8.3
# testpath==0.4.4
# text-unidecode==1.3
# textblob==0.15.3
# textgenrnn==1.4.1
# Theano==1.0.4
# thinc==7.4.0
# tifffile==2020.6.3
# toolz==0.10.0
# torch==1.5.1+cu101
# torchsummary==1.5.1
# torchtext==0.3.1
# torchvision==0.6.1+cu101
# tornado==4.5.3
# tqdm==4.41.1
# traitlets==4.3.3
# tweepy==3.6.0
# typeguard==2.7.1
# typing==3.6.6
# typing-extensions==3.6.6
# tzlocal==1.5.1
# umap-learn==0.4.4
# uritemplate==3.0.1
# urllib3==1.24.3
# vega-datasets==0.8.0
# wasabi==0.7.0
# wcwidth==0.2.5
# webencodings==0.5.1
# websocket-client==0.57.0
# Werkzeug==1.0.1
# widgetsnbextension==3.5.1
# wordcloud==1.5.0
# wrapt==1.12.1
# xarray==0.15.1
# xgboost==0.90
# xkit==0.0.0
# xlrd==1.1.0
# xlwt==1.3.0
# yellowbrick==0.9.1
# zict==2.0.0
# zipp==3.1.0

# %% [markdown]
# ## Run training and evaluation using resnet18

# %%
# !python train_nocv.py \
 --appearance_network resnet18 \
 --pooling CBP \
 --max_epochs 10 \
 --data_root_dir \
 ../../ePillID_data
# Out:
# Namespace(add_persp_aug=1, all_imgs_csv='../../ePillID_data/folds/pilltypeid_nih_sidelbls0.01_metric_5folds/base/pilltypeid_nih_sidelbls0.01_metric_5folds_all.csv', appearance_network='resnet18', arcface_w=0.1, batch_size=48, ce_w=1.0, contrastive_w=1.0, data_root_dir='../../ePillID_data', dropout=0.0, focal_gamma=0.0, focal_w=0.0, img_dir='classification_data', init_lr=0.0001, label_encoder='../../ePillID_data/folds/pilltypeid_nih_sidelbls0.01_metric_5folds/base/label_encoder_pytorch131.pickle', load_config=None, load_mod=None, lr_factor=0.5, lr_patience=2, max_epochs=10, metric_embedding_dim=2048, metric_evaluator_type='cosine', metric_margin=1.0, metric_simul_sidepairs_eval=1, optimizer='adam', pooling='CBP', results_dir='../../ePillID_data/classification_results', sidepairs_agg='post_mean', supress_warnings=False, test_imgs_csv='../../ePillID_data/folds/pilltypeid_nih_sidelbls0.01_metric_5folds/base/pilltypeid_nih_sidelbls0.01_metric_5folds_4.csv', train_with_side_labels=1, triplet_w=1.0, val_imgs_csv='../../ePillID_data/folds/pilltypeid_nih_sidelbls0.01_metric_5folds/base/pilltypeid_nih_sidelbls0.01_metric_5folds_3.csv')
# Attempted to add tag data_root_dir with value ../../ePillID_data
# Attempted to add tag img_dir with value classification_data
# Attempted to add tag supress_warnings with value False
# Attempted to add tag optimizer with value adam
# Attempted to add tag init_lr with value 0.0001
# Attempted to add tag dropout with value 0.0
# Attempted to add tag lr_patience with value 2
# Attempted to add tag lr_factor with value 0.5
# Attempted to add tag batch_size with value 48
# Attempted to add tag max_epochs with value 10
# Attempted to add tag add_persp_aug with value 1
# Attempted to add tag appearance_network with value resnet18
# Attempted to add tag pooling with value CBP
# Attempted to add tag metric_margin with value 1.0
# Attempted to add tag metric_embedding_dim with value 2048
# Attempted to add tag train_with_side_labels with value 1
# Attempted to add tag metric_simul_sidepairs_eval with value 1
# Attempted to add tag sidepairs_agg with value post_mean
# Attempted to add tag metric_evaluator_type with value cosine
# Attempted to add tag ce_w with value 1.0
# Attempted to add tag arcface_w with value 0.1
# Attempted to add tag contrastive_w with value 1.0
# Attempted to add tag triplet_w with value 1.0
# Attempted to add tag focal_w with value 0.0
# Attempted to add tag focal_gamma with value 0.0
# Attempted to add tag load_mod with value None
# Attempted to add tag results_dir with value ../../ePillID_data/classification_results
# Attempted to add tag load_config with value None
# Attempted to add tag all_imgs_csv with value ../../ePillID_data/folds/pilltypeid_nih_sidelbls0.01_metric_5folds/base/pilltypeid_nih_sidelbls0.01_metric_5folds_all.csv
# Attempted to add tag val_imgs_csv with value ../../ePillID_data/folds/pilltypeid_nih_sidelbls0.01_metric_5folds/base/pilltypeid_nih_sidelbls0.01_metric_5folds_3.csv
# Attempted to add tag test_imgs_csv with value ../../ePillID_data/folds/pilltypeid_nih_sidelbls0.01_metric_5folds/base/pilltypeid_nih_sidelbls0.01_metric_5folds_4.csv
# Attempted to add tag label_encoder with value ../../ePillID_data/folds/pilltypeid_nih_sidelbls0.01_metric_5folds/base/label_encoder_pytorch131.pickle
# save_path ../../ePillID_data/classification_results/lr0.0001_dr0.0_lrpatience2_lrfactor0.5_resnet18_202007121035
# WARNING - Fitting a new label encoder at ../../ePillID_data/folds/pilltypeid_nih_sidelbls0.01_metric_5folds/base/label_encoder_pytorch131.pickle
# all_images 13532 train 12042 val 745 test 745
# Attempted to log scalar metric all_images_size:
# 13532
# Attempted to log scalar metric train_size:
# 12042
# Attempted to log scalar metric val_size:
# 745
# Attempted to log scalar metric test_size:
# 745
# ref_only_df 9804 cons_train_df 2238 cons_val_df 745
# Configuring data_dir ../../ePillID_data/classification_data
# Adding perspective transform to augmentation
# train_dataset 12042 val_dataset 10549
# n_classes=4902
# Downloading: "https://download.pytorch.org/models/resnet18-5c106cde.pth" to /root/.cache/torch/checkpoints/resnet18-5c106cde.pth
# 100% 44.7M/44.7M [00:00<00:00, 297MB/s]
# treat front/back as different classes (first half: front, second half: back), n_classes=9804
# MultiheadModel(
#   (embedding_model): EmbeddingModel(
#     (base_model): Newmodel(
#       (features): Sequential(
#         (0): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#         (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#         (3): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#         (4): Sequential(
#           (0): BasicBlock(
#             (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (relu): ReLU(inplace=True)
#             (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (1): BasicBlock(
#             (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (relu): ReLU(inplace=True)
#             (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (5): Sequential(
#           (0): BasicBlock(
#             (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#             (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (relu): ReLU(inplace=True)
#             (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (downsample): Sequential(
#               (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#               (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#           )
#           (1): BasicBlock(
#             (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (relu): ReLU(inplace=True)
#             (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (6): Sequential(
#           (0): BasicBlock(
#             (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#             (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (relu): ReLU(inplace=True)
#             (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (downsample): Sequential(
#               (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#               (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#           )
#           (1): BasicBlock(
#             (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (relu): ReLU(inplace=True)
#             (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (7): Sequential(
#           (0): BasicBlock(
#             (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#             (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (relu): ReLU(inplace=True)
#             (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (downsample): Sequential(
#               (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#               (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#           )
#           (1): BasicBlock(
#             (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (relu): ReLU(inplace=True)
#             (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#       )
#       (representation): CBP(
#         (conv_dr_block): Sequential(
#           (0): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#       )
#       (classifier): Linear(in_features=8192, out_features=2048, bias=True)
#     )
#     (dropout): Dropout(p=0.0, inplace=False)
#     (emb): Sequential(
#       (0): Linear(in_features=2048, out_features=1000, bias=True)
#       (1): BatchNorm1d(1000, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU(inplace=True)
#       (3): Linear(in_features=1000, out_features=2048, bias=True)
#       (4): Tanh()
#     )
#   )
#   (binary_head): BinaryHead(
#     (fc): Sequential(
#       (0): Linear(in_features=2048, out_features=9804, bias=True)
#     )
#   )
#   (margin_head): MarginHead(
#     (fc): MarginLinear()
#   )
# )
# Starting multihead training
# loss_weights {'ce': 1.0, 'arcface': 0.1, 'contrastive': 1.0, 'triplet': 1.0, 'focal': 0.0}
# Will use metric evaluator for validation
# Epoch 0/9
# ----------
# Phase: train
# Epoch 0 train:  36% 89/250 [02:11<03:58,  1.48s/it, acc1=0.00, acc5=0.00, arcface=25.98, ce=10.09, cont=0.51, cont_neg_dist=0.55, cont_pos_dist=0.48, loss=14.18, lr=1.0e-04, metric_loss=1.49, trip=0.98, trip_neg_dist=0.51, trip_pos_dist=0.48]
# Attempted to log scalar metric train_acc1:
# 0.0007206341647705206
# Attempted to log scalar metric train_acc5:
# 0.0024021138915169735
# Attempted to log scalar metric train_lr:
# 0.00010000000000000006
# Attempted to log scalar metric train_loss:
# 14.181264803325389
# Attempted to log scalar metric train_metric_loss:
# 1.490588911502315
# Attempted to log scalar metric train_ce:
# 10.09229173346434
# Attempted to log scalar metric train_arcface:
# 25.98384007782195
# Attempted to log scalar metric train_contrastive:
# 0.5142821225514642
# Attempted to log scalar metric train_triplet:
# 0.9763067880989467
# Attempted to log scalar metric train_triplet_pos_distances:
# 0.4833195070444764
# Attempted to log scalar metric train_triplet_neg_distances:
# 0.5076689785458273
# Attempted to log scalar metric train_contrastive_pos_distances:
# 0.4833195071160822
# Attempted to log scalar metric train_contrastive_neg_distances:
# 0.5450180659266631
# Attempted to log scalar metric train_triplet_dist_diff:
# 0.02434947150135086
# Attempted to log scalar metric train_triplet_pw-avg-precision:
# 0.5770436456757853
# Attempted to log scalar metric train_contrastive_dist_diff:
# 0.06169855881058095
# Attempted to log scalar metric train_contrastive_pw-avg-precision:
# 0.6699328013009036
# Phase: val
# Epoch 0 val:  14% 30/219 [00:25<02:41,  1.17it/s, acc1=0.00, acc5=0.00, arcface=25.73, ce=10.06, cont=0.48, cont_neg_dist=0.74, cont_pos_dist=0.23, loss=14.01, metric_loss=1.38, trip=0.90, trip_neg_dist=0.33, trip_pos_dist=0.23]
# Attempted to log scalar metric val_acc1:
# 0.0014295926087238347
# Attempted to log scalar metric val_acc5:
# 0.0028591852094591984
# Attempted to log scalar metric val_loss:
# 14.01190061207922
# Attempted to log scalar metric val_metric_loss:
# 1.3810994127463068
# Attempted to log scalar metric val_ce:
# 10.057549657269492
# Attempted to log scalar metric val_arcface:
# 25.73251469839122
# Attempted to log scalar metric val_contrastive:
# 0.48335573058029513
# Attempted to log scalar metric val_triplet:
# 0.8977436716851377
# Attempted to log scalar metric val_triplet_pos_distances:
# 0.23139104684108658
# Attempted to log scalar metric val_triplet_neg_distances:
# 0.33479648845560733
# Attempted to log scalar metric val_contrastive_pos_distances:
# 0.231391043707366
# Attempted to log scalar metric val_contrastive_neg_distances:
# 0.7355060882663863
# Attempted to log scalar metric val_triplet_dist_diff:
# 0.10340544161452075
# Attempted to log scalar metric val_triplet_pw-avg-precision:
# 0.6865443778831622
# Attempted to log scalar metric val_contrastive_dist_diff:
# 0.5041150445590203
# Attempted to log scalar metric val_contrastive_pw-avg-precision:
# 0.9923495136876376
# #### Checkpoint ###
# Evaluating metric metrics
# 100% 32/32 [00:11<00:00,  2.72it/s]
# query_img_paths 745 nunique 745 ../../ePillID_data/classification_data/fcn_mix_weight/dc_224/10.jpg
# query_labels 745 nunique 192
# 100% 409/409 [02:31<00:00,  2.70it/s]
# Completed the eval model function. query:torch.Size([745, 2048]), ref:torch.Size([9804, 2048])
# Creating Torch cosine sim provider for metric evaluator
# Found 4902 classes in the references
# Evaluation will be performed in 611 simulated 2-side pairs from 613 consumer images of 141 labels.
# Calculate distance matrix between all the labels 4902 and consumer-queries 611
# Avg. time elapsed per metric query 0m 0s
# qry_lbl_sim_matrix torch.Size([611, 4902])
# torch.Size([611, 4902])
# torch.Size([611])
# torch.Size([611])
# torch.Size([611, 4902])
# torch.Size([611])
# torch.Size([611])
# Evaluation complete in 2m 45s
# {'top1-acc': 0.1243862509727478, 'top5-acc': 0.3600654602050781}
# all_avg_precision (611, 7) (611, 4902) (611, 4902) 4902 611
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_ranking.py:677: RuntimeWarning: invalid value encountered in true_divide
#   recall = tps / tps[-1]
# Attempted to log scalar metric val_top1-acc_metric:
# 0.1243862509727478
# Attempted to log scalar metric val_top5-acc_metric:
# 0.3600654602050781
# Attempted to log scalar metric val_map_metric:
# 0.2412337364769986
# Attempted to log scalar metric val_map_at_1_metric:
# 0.12438625204582651
# Attempted to log scalar metric val_gap_metric:
# 0.014708584567388279
# Attempted to log scalar metric val_gap_at_1_metric:
# 0.12842170508737197
# Attempted to log scalar metric val_micro-ap_metric:
# 0.014708584567388279
# Saving the best model state dict, 0.014708584567388279, 0
#
# Epoch 1/9
# ----------
# Phase: train
# Epoch 1 train:  36% 89/250 [02:08<03:51,  1.44s/it, acc1=0.00, acc5=0.02, arcface=24.46, ce=8.17, cont=0.47, cont_neg_dist=0.59, cont_pos_dist=0.36, loss=11.98, lr=1.0e-04, metric_loss=1.36, trip=0.89, trip_neg_dist=0.47, trip_pos_dist=0.36]
# Attempted to log scalar metric train_acc1:
# 0.0045530793935296176
# Attempted to log scalar metric train_acc5:
# 0.016295231590857617
# Attempted to log scalar metric train_lr:
# 0.00010000000000000009
# Attempted to log scalar metric train_loss:
# 11.975992743699864
# Attempted to log scalar metric train_metric_loss:
# 1.363016843395841
# Attempted to log scalar metric train_ce:
# 8.167063101515506
# Attempted to log scalar metric train_arcface:
# 24.459126226341528
# Attempted to log scalar metric train_contrastive:
# 0.4746836909081134
# Attempted to log scalar metric train_triplet:
# 0.8883331486597753
# Attempted to log scalar metric train_triplet_pos_distances:
# 0.3589628064632416
# Attempted to log scalar metric train_triplet_neg_distances:
# 0.47154993052942207
# Attempted to log scalar metric train_contrastive_pos_distances:
# 0.3589628078133227
# Attempted to log scalar metric train_contrastive_neg_distances:
# 0.5899929730279977
# Attempted to log scalar metric train_triplet_dist_diff:
# 0.11258712406618049
# Attempted to log scalar metric train_triplet_pw-avg-precision:
# 0.7114906665798497
# Attempted to log scalar metric train_contrastive_dist_diff:
# 0.231030165214675
# Attempted to log scalar metric train_contrastive_pw-avg-precision:
# 0.8376676250711015
# Phase: val
# Epoch 1 val:  14% 30/219 [00:23<02:28,  1.27it/s, acc1=0.00, acc5=0.01, arcface=25.92, ce=10.64, cont=0.45, cont_neg_dist=0.66, cont_pos_dist=0.24, loss=14.49, metric_loss=1.26, trip=0.81, trip_neg_dist=0.43, trip_pos_dist=0.24]
# Attempted to log scalar metric val_acc1:
# 0.0029197080101627504
# Attempted to log scalar metric val_acc5:
# 0.011678832084158042
# Attempted to log scalar metric val_loss:
# 14.494759712080016
# Attempted to log scalar metric val_metric_loss:
# 1.2619166573033715
# Attempted to log scalar metric val_ce:
# 10.64105525747703
# Attempted to log scalar metric val_arcface:
# 25.91787728776027
# Attempted to log scalar metric val_contrastive:
# 0.450235925016612
# Attempted to log scalar metric val_triplet:
# 0.8116807230632671
# Attempted to log scalar metric val_triplet_pos_distances:
# 0.2414658467266217
# Attempted to log scalar metric val_triplet_neg_distances:
# 0.4316966466802306
# Attempted to log scalar metric val_contrastive_pos_distances:
# 0.24146585026619372
# Attempted to log scalar metric val_contrastive_neg_distances:
# 0.6577692766867774
# Attempted to log scalar metric val_triplet_dist_diff:
# 0.19023079995360892
# Attempted to log scalar metric val_triplet_pw-avg-precision:
# 0.8001743036751892
# Attempted to log scalar metric val_contrastive_dist_diff:
# 0.4163034264205837
# Attempted to log scalar metric val_contrastive_pw-avg-precision:
# 0.9331881231072259
#
# Epoch 2/9
# ----------
# Phase: train
# Epoch 2 train:  35% 88/250 [02:05<03:51,  1.43s/it, acc1=0.01, acc5=0.04, arcface=23.61, ce=7.22, cont=0.43, cont_neg_dist=0.54, cont_pos_dist=0.32, loss=10.81, lr=1.0e-04, metric_loss=1.23, trip=0.80, trip_neg_dist=0.52, trip_pos_dist=0.32]
# Attempted to log scalar metric train_acc1:
# 0.008452064849110624
# Attempted to log scalar metric train_acc5:
# 0.039603960929958895
# Attempted to log scalar metric train_lr:
# 0.00010000000000000011
# Attempted to log scalar metric train_loss:
# 10.814330386125187
# Attempted to log scalar metric train_metric_loss:
# 1.229790917213802
# Attempted to log scalar metric train_ce:
# 7.224017652443888
# Attempted to log scalar metric train_arcface:
# 23.605218034296097
# Attempted to log scalar metric train_contrastive:
# 0.4276369059756596
# Attempted to log scalar metric train_triplet:
# 0.8021540081578733
# Attempted to log scalar metric train_triplet_pos_distances:
# 0.3171013547773779
# Attempted to log scalar metric train_triplet_neg_distances:
# 0.5168167527429669
# Attempted to log scalar metric train_contrastive_pos_distances:
# 0.31710135489339664
# Attempted to log scalar metric train_contrastive_neg_distances:
# 0.5362163782264775
# Attempted to log scalar metric train_triplet_dist_diff:
# 0.19971539796558901
# Attempted to log scalar metric train_triplet_pw-avg-precision:
# 0.8121321531831673
# Attempted to log scalar metric train_contrastive_dist_diff:
# 0.21911502333308086
# Attempted to log scalar metric train_contrastive_pw-avg-precision:
# 0.8213211895222263
# Phase: val
# Epoch 2 val:  14% 30/219 [00:24<02:32,  1.24it/s, acc1=0.01, acc5=0.01, arcface=25.84, ce=10.56, cont=0.42, cont_neg_dist=0.65, cont_pos_dist=0.19, loss=14.32, metric_loss=1.18, trip=0.76, trip_neg_dist=0.44, trip_pos_dist=0.19]
# Attempted to log scalar metric val_acc1:
# 0.0056298382470173205
# Attempted to log scalar metric val_acc5:
# 0.009148487253645454
# Attempted to log scalar metric val_loss:
# 14.324274626187586
# Attempted to log scalar metric val_metric_loss:
# 1.1807624393579912
# Attempted to log scalar metric val_ce:
# 10.559050717712875
# Attempted to log scalar metric val_arcface:
# 25.84461429469775
# Attempted to log scalar metric val_contrastive:
# 0.42100002596195446
# Attempted to log scalar metric val_triplet:
# 0.7597624023643537
# Attempted to log scalar metric val_triplet_pos_distances:
# 0.1941543648485753
# Attempted to log scalar metric val_triplet_neg_distances:
# 0.43623961716932486
# Attempted to log scalar metric val_contrastive_pos_distances:
# 0.19415436440596653
# Attempted to log scalar metric val_contrastive_neg_distances:
# 0.6453038067932345
# Attempted to log scalar metric val_triplet_dist_diff:
# 0.24208525232074957
# Attempted to log scalar metric val_triplet_pw-avg-precision:
# 0.8519708892696063
# Attempted to log scalar metric val_contrastive_dist_diff:
# 0.45114944238726795
# Attempted to log scalar metric val_contrastive_pw-avg-precision:
# 0.9765678843155079
#
# Epoch 3/9
# ----------
# Phase: train
# Epoch 3 train:  36% 89/250 [02:08<03:51,  1.44s/it, acc1=0.02, acc5=0.08, arcface=23.02, ce=6.58, cont=0.39, cont_neg_dist=0.47, cont_pos_dist=0.29, loss=9.98, lr=1.0e-04, metric_loss=1.10, trip=0.72, trip_neg_dist=0.58, trip_pos_dist=0.29]
# Attempted to log scalar metric train_acc1:
# 0.0202236498918543
# Attempted to log scalar metric train_acc5:
# 0.07875327249071994
# Attempted to log scalar metric train_lr:
# 0.00010000000000000005
# Attempted to log scalar metric train_loss:
# 9.984760896608769
# Attempted to log scalar metric train_metric_loss:
# 1.101591215626047
# Attempted to log scalar metric train_ce:
# 6.581159111887905
# Attempted to log scalar metric train_arcface:
# 23.02010470573431
# Attempted to log scalar metric train_contrastive:
# 0.3855483503872628
# Attempted to log scalar metric train_triplet:
# 0.716042860140552
# Attempted to log scalar metric train_triplet_pos_distances:
# 0.2941368080728694
# Attempted to log scalar metric train_triplet_neg_distances:
# 0.5801380334727272
# Attempted to log scalar metric train_contrastive_pos_distances:
# 0.2941368085330003
# Attempted to log scalar metric train_contrastive_neg_distances:
# 0.4745877257718609
# Attempted to log scalar metric train_triplet_dist_diff:
# 0.2860012253998578
# Attempted to log scalar metric train_triplet_pw-avg-precision:
# 0.8881371145761803
# Attempted to log scalar metric train_contrastive_dist_diff:
# 0.18045091723886064
# Attempted to log scalar metric train_contrastive_pw-avg-precision:
# 0.7964245926300764
# Phase: val
# Epoch 3 val:  13% 29/219 [00:23<02:34,  1.23it/s, acc1=0.01, acc5=0.02, arcface=25.62, ce=10.49, cont=0.39, cont_neg_dist=0.59, cont_pos_dist=0.19, loss=14.13, metric_loss=1.08, trip=0.69, trip_neg_dist=0.50, trip_pos_dist=0.19]
# Attempted to log scalar metric val_acc1:
# 0.010263929707530744
# Attempted to log scalar metric val_acc5:
# 0.024926686286653156
# Attempted to log scalar metric val_loss:
# 14.13131366936692
# Attempted to log scalar metric val_metric_loss:
# 1.0815161290493878
# Attempted to log scalar metric val_ce:
# 10.488214604665806
# Attempted to log scalar metric val_arcface:
# 25.61582752546607
# Attempted to log scalar metric val_contrastive:
# 0.3905233671544584
# Attempted to log scalar metric val_triplet:
# 0.6909927599066513
# Attempted to log scalar metric val_triplet_pos_distances:
# 0.19171610269091122
# Attempted to log scalar metric val_triplet_neg_distances:
# 0.5000846717385767
# Attempted to log scalar metric val_contrastive_pos_distances:
# 0.19171609954804095
# Attempted to log scalar metric val_contrastive_neg_distances:
# 0.5900567438134753
# Attempted to log scalar metric val_triplet_dist_diff:
# 0.3083685690476655
# Attempted to log scalar metric val_triplet_pw-avg-precision:
# 0.9138590228465381
# Attempted to log scalar metric val_contrastive_dist_diff:
# 0.39834064426543436
# Attempted to log scalar metric val_contrastive_pw-avg-precision:
# 0.9731053778969923
#
# Epoch 4/9
# ----------
# Phase: train
# Epoch 4 train:  36% 89/250 [02:06<03:48,  1.42s/it, acc1=0.03, acc5=0.14, arcface=22.47, ce=6.05, cont=0.37, cont_neg_dist=0.46, cont_pos_dist=0.27, loss=9.35, lr=1.0e-04, metric_loss=1.05, trip=0.68, trip_neg_dist=0.59, trip_pos_dist=0.27]
# Attempted to log scalar metric train_acc1:
# 0.031556299713266796
# Attempted to log scalar metric train_acc5:
# 0.13674396501077923
# Attempted to log scalar metric train_lr:
# 0.00010000000000000003
# Attempted to log scalar metric train_loss:
# 9.347977865776775
# Attempted to log scalar metric train_metric_loss:
# 1.0462504244437778
# Attempted to log scalar metric train_ce:
# 6.054412094109828
# Attempted to log scalar metric train_arcface:
# 22.473153060741637
# Attempted to log scalar metric train_contrastive:
# 0.3659978718057136
# Attempted to log scalar metric train_triplet:
# 0.6802525486553966
# Attempted to log scalar metric train_triplet_pos_distances:
# 0.2728994077921596
# Attempted to log scalar metric train_triplet_neg_distances:
# 0.5934331428169011
# Attempted to log scalar metric train_contrastive_pos_distances:
# 0.27289940649177213
# Attempted to log scalar metric train_contrastive_neg_distances:
# 0.45785713322286553
# Attempted to log scalar metric train_triplet_dist_diff:
# 0.3205337350247415
# Attempted to log scalar metric train_triplet_pw-avg-precision:
# 0.9095175791810879
# Attempted to log scalar metric train_contrastive_dist_diff:
# 0.1849577267310934
# Attempted to log scalar metric train_contrastive_pw-avg-precision:
# 0.8221154179515795
# Phase: val
# Epoch 4 val:  13% 29/219 [00:23<02:33,  1.24it/s, acc1=0.00, acc5=0.02, arcface=25.61, ce=10.59, cont=0.39, cont_neg_dist=0.61, cont_pos_dist=0.16, loss=14.22, metric_loss=1.07, trip=0.69, trip_neg_dist=0.48, trip_pos_dist=0.16]
# Attempted to log scalar metric val_acc1:
# 0.0036656891236141803
# Attempted to log scalar metric val_acc5:
# 0.016129032457438557
# Attempted to log scalar metric val_loss:
# 14.224456540300698
# Attempted to log scalar metric val_metric_loss:
# 1.0748148414571264
# Attempted to log scalar metric val_ce:
# 10.588560152613173
# Attempted to log scalar metric val_arcface:
# 25.610815860658796
# Attempted to log scalar metric val_contrastive:
# 0.388428144178782
# Attempted to log scalar metric val_triplet:
# 0.6863866919034387
# Attempted to log scalar metric val_triplet_pos_distances:
# 0.16254297759285016
# Attempted to log scalar metric val_triplet_neg_distances:
# 0.47654249349878247
# Attempted to log scalar metric val_contrastive_pos_distances:
# 0.16254297550492933
# Attempted to log scalar metric val_contrastive_neg_distances:
# 0.6143496504663366
# Attempted to log scalar metric val_triplet_dist_diff:
# 0.31399951590593234
# Attempted to log scalar metric val_triplet_pw-avg-precision:
# 0.9316470986766511
# Attempted to log scalar metric val_contrastive_dist_diff:
# 0.45180667496140725
# Attempted to log scalar metric val_contrastive_pw-avg-precision:
# 0.9880757645245901
#
# Epoch 5/9
# ----------
# Phase: train
# Epoch 5 train:  36% 89/250 [02:06<03:48,  1.42s/it, acc1=0.05, acc5=0.19, arcface=22.09, ce=5.66, cont=0.36, cont_neg_dist=0.43, cont_pos_dist=0.28, loss=8.89, lr=1.0e-04, metric_loss=1.02, trip=0.67, trip_neg_dist=0.61, trip_pos_dist=0.28]
# Attempted to log scalar metric train_acc1:
# 0.049231508532923705
# Attempted to log scalar metric train_acc5:
# 0.19356388269183758
# Attempted to log scalar metric train_lr:
# 0.00010000000000000007
# Attempted to log scalar metric train_loss:
# 8.888641305203397
# Attempted to log scalar metric train_metric_loss:
# 1.0216636920668092
# Attempted to log scalar metric train_ce:
# 5.658051463643824
# Attempted to log scalar metric train_arcface:
# 22.089261207067544
# Attempted to log scalar metric train_contrastive:
# 0.35653600166126814
# Attempted to log scalar metric train_triplet:
# 0.6651276887164564
# Attempted to log scalar metric train_triplet_pos_distances:
# 0.27892674600184825
# Attempted to log scalar metric train_triplet_neg_distances:
# 0.6143619008755936
# Attempted to log scalar metric train_contrastive_pos_distances:
# 0.2789267477338756
# Attempted to log scalar metric train_contrastive_neg_distances:
# 0.4337073244032782
# Attempted to log scalar metric train_triplet_dist_diff:
# 0.33543515487374537
# Attempted to log scalar metric train_triplet_pw-avg-precision:
# 0.9149350201783816
# Attempted to log scalar metric train_contrastive_dist_diff:
# 0.1547805766694026
# Attempted to log scalar metric train_contrastive_pw-avg-precision:
# 0.7782847471264491
# Phase: val
# Epoch 5 val:  13% 29/219 [00:23<02:32,  1.25it/s, acc1=0.02, acc5=0.03, arcface=25.63, ce=10.63, cont=0.38, cont_neg_dist=0.59, cont_pos_dist=0.16, loss=14.25, metric_loss=1.05, trip=0.68, trip_neg_dist=0.49, trip_pos_dist=0.16]
# Attempted to log scalar metric val_acc1:
# 0.015362107019868749
# Attempted to log scalar metric val_acc5:
# 0.029992685378709673
# Attempted to log scalar metric val_loss:
# 14.249756432137701
# Attempted to log scalar metric val_metric_loss:
# 1.052924406685442
# Attempted to log scalar metric val_ce:
# 10.63367186380985
# Attempted to log scalar metric val_arcface:
# 25.631599896479106
# Attempted to log scalar metric val_contrastive:
# 0.3750338893391917
# Attempted to log scalar metric val_triplet:
# 0.6778905122665567
# Attempted to log scalar metric val_triplet_pos_distances:
# 0.16295451425467145
# Attempted to log scalar metric val_triplet_neg_distances:
# 0.48660334438481745
# Attempted to log scalar metric val_contrastive_pos_distances:
# 0.16295451415562384
# Attempted to log scalar metric val_contrastive_neg_distances:
# 0.5852443239097229
# Attempted to log scalar metric val_triplet_dist_diff:
# 0.323648830130146
# Attempted to log scalar metric val_triplet_pw-avg-precision:
# 0.9320664254358444
# Attempted to log scalar metric val_contrastive_dist_diff:
# 0.4222898097540991
# Attempted to log scalar metric val_contrastive_pw-avg-precision:
# 0.9866151270783837
# #### Checkpoint ###
# Evaluating metric metrics
# 100% 32/32 [00:11<00:00,  2.80it/s]
# query_img_paths 745 nunique 745 ../../ePillID_data/classification_data/fcn_mix_weight/dc_224/10.jpg
# query_labels 745 nunique 192
# 100% 409/409 [02:25<00:00,  2.81it/s]
# Completed the eval model function. query:torch.Size([745, 2048]), ref:torch.Size([9804, 2048])
# Creating Torch cosine sim provider for metric evaluator
# Found 4902 classes in the references
# Evaluation will be performed in 611 simulated 2-side pairs from 613 consumer images of 141 labels.
# Calculate distance matrix between all the labels 4902 and consumer-queries 611
# Avg. time elapsed per metric query 0m 0s
# qry_lbl_sim_matrix torch.Size([611, 4902])
# torch.Size([611, 4902])
# torch.Size([611])
# torch.Size([611])
# torch.Size([611, 4902])
# torch.Size([611])
# torch.Size([611])
# Evaluation complete in 2m 38s
# {'top1-acc': 0.607201337814331, 'top5-acc': 0.8756137490272522}
# all_avg_precision (611, 7) (611, 4902) (611, 4902) 4902 611
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_ranking.py:677: RuntimeWarning: invalid value encountered in true_divide
#   recall = tps / tps[-1]
# Attempted to log scalar metric val_top1-acc_metric:
# 0.607201337814331
# Attempted to log scalar metric val_top5-acc_metric:
# 0.8756137490272522
# Attempted to log scalar metric val_map_metric:
# 0.7259299484520537
# Attempted to log scalar metric val_map_at_1_metric:
# 0.6072013093289689
# Attempted to log scalar metric val_gap_metric:
# 0.29401833317665305
# Attempted to log scalar metric val_gap_at_1_metric:
# 0.7074460911114795
# Attempted to log scalar metric val_micro-ap_metric:
# 0.29401833317665305
# Saving the best model state dict, 0.29401833317665305, 1
#
# Epoch 6/9
# ----------
# Phase: train
# Epoch 6 train:  36% 89/250 [02:11<03:56,  1.47s/it, acc1=0.07, acc5=0.27, arcface=21.78, ce=5.40, cont=0.35, cont_neg_dist=0.41, cont_pos_dist=0.29, loss=8.59, lr=1.0e-04, metric_loss=1.01, trip=0.66, trip_neg_dist=0.63, trip_pos_dist=0.29]
# Attempted to log scalar metric train_acc1:
# 0.07480879688375482
# Attempted to log scalar metric train_acc5:
# 0.27198853075636076
# Attempted to log scalar metric train_lr:
# 0.00010000000000000007
# Attempted to log scalar metric train_loss:
# 8.587736394619622
# Attempted to log scalar metric train_metric_loss:
# 1.0100188939965706
# Attempted to log scalar metric train_ce:
# 5.399635184905269
# Attempted to log scalar metric train_arcface:
# 21.780822646321575
# Attempted to log scalar metric train_contrastive:
# 0.35025838785315105
# Attempted to log scalar metric train_triplet:
# 0.6597605048755387
# Attempted to log scalar metric train_triplet_pos_distances:
# 0.28640146802107186
# Attempted to log scalar metric train_triplet_neg_distances:
# 0.6270231463993727
# Attempted to log scalar metric train_contrastive_pos_distances:
# 0.2864014664209472
# Attempted to log scalar metric train_contrastive_neg_distances:
# 0.41368135437012177
# Attempted to log scalar metric train_triplet_dist_diff:
# 0.3406216783783009
# Attempted to log scalar metric train_triplet_pw-avg-precision:
# 0.9289804448996145
# Attempted to log scalar metric train_contrastive_dist_diff:
# 0.12727988794917455
# Attempted to log scalar metric train_contrastive_pw-avg-precision:
# 0.7596161769734857
# Phase: val
# Epoch 6 val:  14% 30/219 [00:24<02:35,  1.21it/s, acc1=0.01, acc5=0.02, arcface=25.44, ce=10.45, cont=0.36, cont_neg_dist=0.54, cont_pos_dist=0.18, loss=14.01, metric_loss=1.02, trip=0.66, trip_neg_dist=0.53, trip_pos_dist=0.18]
# Attempted to log scalar metric val_acc1:
# 0.007953723915465397
# Attempted to log scalar metric val_acc5:
# 0.023138105925859444
# Attempted to log scalar metric val_loss:
# 14.00975194670373
# Attempted to log scalar metric val_metric_loss:
# 1.017142134779877
# Attempted to log scalar metric val_ce:
# 10.44832564400144
# Attempted to log scalar metric val_arcface:
# 25.442840363784537
# Attempted to log scalar metric val_contrastive:
# 0.3615572559859385
# Attempted to log scalar metric val_triplet:
# 0.6555848805178617
# Attempted to log scalar metric val_triplet_pos_distances:
# 0.18357417270735837
# Attempted to log scalar metric val_triplet_neg_distances:
# 0.5307313174398613
# Attempted to log scalar metric val_contrastive_pos_distances:
# 0.1835741732480391
# Attempted to log scalar metric val_contrastive_neg_distances:
# 0.5366571597506242
# Attempted to log scalar metric val_triplet_dist_diff:
# 0.347157144732503
# Attempted to log scalar metric val_triplet_pw-avg-precision:
# 0.9444803780822139
# Attempted to log scalar metric val_contrastive_dist_diff:
# 0.3530829865025851
# Attempted to log scalar metric val_contrastive_pw-avg-precision:
# 0.9693337381682513
#
# Epoch 7/9
# ----------
# Phase: train
# Epoch 7 train:  36% 89/250 [02:10<03:56,  1.47s/it, acc1=0.10, acc5=0.35, arcface=21.46, ce=4.99, cont=0.33, cont_neg_dist=0.38, cont_pos_dist=0.27, loss=8.08, lr=1.0e-04, metric_loss=0.95, trip=0.62, trip_neg_dist=0.65, trip_pos_dist=0.27]
# Attempted to log scalar metric train_acc1:
# 0.10291308643600575
# Attempted to log scalar metric train_acc5:
# 0.35482330832527215
# Attempted to log scalar metric train_lr:
# 0.00010000000000000006
# Attempted to log scalar metric train_loss:
# 8.083669007678429
# Attempted to log scalar metric train_metric_loss:
# 0.9502369382889245
# Attempted to log scalar metric train_ce:
# 4.987831663834901
# Attempted to log scalar metric train_arcface:
# 21.456003438663572
# Attempted to log scalar metric train_contrastive:
# 0.3294282859331842
# Attempted to log scalar metric train_triplet:
# 0.6208086549424511
# Attempted to log scalar metric train_triplet_pos_distances:
# 0.27388658924996
# Attempted to log scalar metric train_triplet_neg_distances:
# 0.653532355569225
# Attempted to log scalar metric train_contrastive_pos_distances:
# 0.2738865895553699
# Attempted to log scalar metric train_contrastive_neg_distances:
# 0.3844568783806209
# Attempted to log scalar metric train_triplet_dist_diff:
# 0.37964576631926494
# Attempted to log scalar metric train_triplet_pw-avg-precision:
# 0.9387906976313669
# Attempted to log scalar metric train_contrastive_dist_diff:
# 0.11057028882525105
# Attempted to log scalar metric train_contrastive_pw-avg-precision:
# 0.7047428830372588
# Phase: val
# Epoch 7 val:  14% 30/219 [00:23<02:29,  1.27it/s, acc1=0.01, acc5=0.02, arcface=25.26, ce=10.23, cont=0.35, cont_neg_dist=0.52, cont_pos_dist=0.19, loss=13.74, metric_loss=0.99, trip=0.63, trip_neg_dist=0.56, trip_pos_dist=0.19]
# Attempted to log scalar metric val_acc1:
# 0.008771929910341114
# Attempted to log scalar metric val_acc5:
# 0.023391812996209016
# Attempted to log scalar metric val_loss:
# 13.74205880276641
# Attempted to log scalar metric val_metric_loss:
# 0.9862531126416915
# Attempted to log scalar metric val_ce:
# 10.229480426911024
# Attempted to log scalar metric val_arcface:
# 25.26325087519417
# Attempted to log scalar metric val_contrastive:
# 0.35463246616006594
# Attempted to log scalar metric val_triplet:
# 0.6316206527340134
# Attempted to log scalar metric val_triplet_pos_distances:
# 0.19170538199079387
# Attempted to log scalar metric val_triplet_neg_distances:
# 0.5612849408651099
# Attempted to log scalar metric val_contrastive_pos_distances:
# 0.19170537950361477
# Attempted to log scalar metric val_contrastive_neg_distances:
# 0.5163420450599755
# Attempted to log scalar metric val_triplet_dist_diff:
# 0.36957955887431604
# Attempted to log scalar metric val_triplet_pw-avg-precision:
# 0.9258223361670356
# Attempted to log scalar metric val_contrastive_dist_diff:
# 0.3246366655563607
# Attempted to log scalar metric val_contrastive_pw-avg-precision:
# 0.9509661681685764
#
# Epoch 8/9
# ----------
# Phase: train
# Epoch 8 train:  36% 89/250 [02:08<03:51,  1.44s/it, acc1=0.14, acc5=0.42, arcface=21.32, ce=4.78, cont=0.32, cont_neg_dist=0.37, cont_pos_dist=0.27, loss=7.85, lr=1.0e-04, metric_loss=0.93, trip=0.61, trip_neg_dist=0.66, trip_pos_dist=0.27]
# Attempted to log scalar metric train_acc1:
# 0.1422715236012666
# Attempted to log scalar metric train_acc5:
# 0.41620449048440256
# Attempted to log scalar metric train_lr:
# 0.00010000000000000006
# Attempted to log scalar metric train_loss:
# 7.849918243940808
# Attempted to log scalar metric train_metric_loss:
# 0.933405112467072
# Attempted to log scalar metric train_ce:
# 4.784757685540583
# Attempted to log scalar metric train_arcface:
# 21.31755330932264
# Attempted to log scalar metric train_contrastive:
# 0.32209381759022987
# Attempted to log scalar metric train_triplet:
# 0.611311295793118
# Attempted to log scalar metric train_triplet_pos_distances:
# 0.2725889514779929
# Attempted to log scalar metric train_triplet_neg_distances:
# 0.6612980463025645
# Attempted to log scalar metric train_contrastive_pos_distances:
# 0.2725889484039519
# Attempted to log scalar metric train_contrastive_neg_distances:
# 0.3714722844323292
# Attempted to log scalar metric train_triplet_dist_diff:
# 0.3887090948245716
# Attempted to log scalar metric train_triplet_pw-avg-precision:
# 0.9542345783849739
# Attempted to log scalar metric train_contrastive_dist_diff:
# 0.09888333602837729
# Attempted to log scalar metric train_contrastive_pw-avg-precision:
# 0.6949210424537515
# Phase: val
# Epoch 8 val:  14% 30/219 [00:24<02:32,  1.24it/s, acc1=0.02, acc5=0.03, arcface=25.17, ce=10.05, cont=0.34, cont_neg_dist=0.50, cont_pos_dist=0.19, loss=13.55, metric_loss=0.98, trip=0.64, trip_neg_dist=0.55, trip_pos_dist=0.19]
# Attempted to log scalar metric val_acc1:
# 0.015272727248343554
# Attempted to log scalar metric val_acc5:
# 0.03272727277739482
# Attempted to log scalar metric val_loss:
# 13.549212667291815
# Attempted to log scalar metric val_metric_loss:
# 0.9804939888173884
# Attempted to log scalar metric val_ce:
# 10.051239307750356
# Attempted to log scalar metric val_arcface:
# 25.174792898004704
# Attempted to log scalar metric val_contrastive:
# 0.343833777514371
# Attempted to log scalar metric val_triplet:
# 0.6366602023731579
# Attempted to log scalar metric val_triplet_pos_distances:
# 0.18665670913501378
# Attempted to log scalar metric val_triplet_neg_distances:
# 0.5501428939130184
# Attempted to log scalar metric val_contrastive_pos_distances:
# 0.18665671065776018
# Attempted to log scalar metric val_contrastive_neg_distances:
# 0.500798415833146
# Attempted to log scalar metric val_triplet_dist_diff:
# 0.36348618477800465
# Attempted to log scalar metric val_triplet_pw-avg-precision:
# 0.9500471587177521
# Attempted to log scalar metric val_contrastive_dist_diff:
# 0.3141417051753858
# Attempted to log scalar metric val_contrastive_pw-avg-precision:
# 0.9523948259457456
#
# Epoch 9/9
# ----------
# Phase: train
# Epoch 9 train:  36% 89/250 [02:10<03:56,  1.47s/it, acc1=0.19, acc5=0.50, arcface=20.89, ce=4.44, cont=0.31, cont_neg_dist=0.35, cont_pos_dist=0.27, loss=7.42, lr=1.0e-04, metric_loss=0.90, trip=0.59, trip_neg_dist=0.69, trip_pos_dist=0.27]
# Attempted to log scalar metric train_acc1:
# 0.19063465828830892
# Attempted to log scalar metric train_acc5:
# 0.495127173495287
# Attempted to log scalar metric train_lr:
# 0.00010000000000000009
# Attempted to log scalar metric train_loss:
# 7.424094261339903
# Attempted to log scalar metric train_metric_loss:
# 0.8996468508983129
# Attempted to log scalar metric train_ce:
# 4.435548806717539
# Attempted to log scalar metric train_arcface:
# 20.888985718404534
# Attempted to log scalar metric train_contrastive:
# 0.31051045200349825
# Attempted to log scalar metric train_triplet:
# 0.589136401434423
# Attempted to log scalar metric train_triplet_pos_distances:
# 0.27326536451646793
# Attempted to log scalar metric train_triplet_neg_distances:
# 0.6855722311166058
# Attempted to log scalar metric train_contrastive_pos_distances:
# 0.27326536503421417
# Attempted to log scalar metric train_contrastive_neg_distances:
# 0.34617763439965554
# Attempted to log scalar metric train_triplet_dist_diff:
# 0.4123068666001379
# Attempted to log scalar metric train_triplet_pw-avg-precision:
# 0.9618216188860745
# Attempted to log scalar metric train_contrastive_dist_diff:
# 0.07291226936544137
# Attempted to log scalar metric train_contrastive_pw-avg-precision:
# 0.6390542694289862
# Phase: val
# Epoch 9 val:  14% 30/219 [00:24<02:33,  1.23it/s, acc1=0.02, acc5=0.04, arcface=25.16, ce=10.09, cont=0.34, cont_neg_dist=0.50, cont_pos_dist=0.18, loss=13.56, metric_loss=0.95, trip=0.61, trip_neg_dist=0.57, trip_pos_dist=0.18]
# Attempted to log scalar metric val_acc1:
# 0.017946877343645647
# Attempted to log scalar metric val_acc5:
# 0.035893755046983715
# Attempted to log scalar metric val_loss:
# 13.558453240843019
# Attempted to log scalar metric val_metric_loss:
# 0.9486763575739425
# Attempted to log scalar metric val_ce:
# 10.09347260537459
# Attempted to log scalar metric val_arcface:
# 25.163042479252866
# Attempted to log scalar metric val_contrastive:
# 0.33973737498538065
# Attempted to log scalar metric val_triplet:
# 0.6089389830806319
# Attempted to log scalar metric val_triplet_pos_distances:
# 0.179223024915674
# Attempted to log scalar metric val_triplet_neg_distances:
# 0.5705743311039858
# Attempted to log scalar metric val_contrastive_pos_distances:
# 0.1792230238894821
# Attempted to log scalar metric val_contrastive_neg_distances:
# 0.5005237346827728
# Attempted to log scalar metric val_triplet_dist_diff:
# 0.3913513061883118
# Attempted to log scalar metric val_triplet_pw-avg-precision:
# 0.9474103955166084
# Attempted to log scalar metric val_contrastive_dist_diff:
# 0.3213007107932907
# Attempted to log scalar metric val_contrastive_pw-avg-precision:
# 0.9478750369178421
#
# Training complete in 31m 7s
# completed train()
# val_metrics {'best_epoch': 1, 'acc1': 0.0029197080101627504, 'acc5': 0.011678832084158042, 'loss': 14.494759712080016, 'metric_loss': 1.2619166573033715, 'ce': 10.64105525747703, 'arcface': 25.91787728776027, 'contrastive': 0.450235925016612, 'triplet': 0.8116807230632671, 'triplet_pos_distances': 0.2414658467266217, 'triplet_neg_distances': 0.4316966466802306, 'contrastive_pos_distances': 0.24146585026619372, 'contrastive_neg_distances': 0.6577692766867774, 'triplet_dist_diff': 0.19023079995360892, 'triplet_pw-avg-precision': 0.8001743036751892, 'contrastive_dist_diff': 0.4163034264205837, 'contrastive_pw-avg-precision': 0.9331881231072259, 'top1-acc': 0.607201337814331, 'top5-acc': 0.8756137490272522, 'map': 0.7259299484520537, 'map_at_1': 0.6072013093289689, 'gap': 0.29401833317665305, 'gap_at_1': 0.7074460911114795, 'micro-ap': 0.29401833317665305}
# Attempted to log scalar metric val_acc1:
# 0.0029197080101627504
# Attempted to log scalar metric val_acc5:
# 0.011678832084158042
# Attempted to log scalar metric val_loss:
# 14.494759712080016
# Attempted to log scalar metric val_metric_loss:
# 1.2619166573033715
# Attempted to log scalar metric val_ce:
# 10.64105525747703
# Attempted to log scalar metric val_arcface:
# 25.91787728776027
# Attempted to log scalar metric val_contrastive:
# 0.450235925016612
# Attempted to log scalar metric val_triplet:
# 0.8116807230632671
# Attempted to log scalar metric val_triplet_pos_distances:
# 0.2414658467266217
# Attempted to log scalar metric val_triplet_neg_distances:
# 0.4316966466802306
# Attempted to log scalar metric val_contrastive_pos_distances:
# 0.24146585026619372
# Attempted to log scalar metric val_contrastive_neg_distances:
# 0.6577692766867774
# Attempted to log scalar metric val_triplet_dist_diff:
# 0.19023079995360892
# Attempted to log scalar metric val_triplet_pw-avg-precision:
# 0.8001743036751892
# Attempted to log scalar metric val_contrastive_dist_diff:
# 0.4163034264205837
# Attempted to log scalar metric val_contrastive_pw-avg-precision:
# 0.9331881231072259
# Attempted to log scalar metric val_top1-acc:
# 0.607201337814331
# Attempted to log scalar metric val_top5-acc:
# 0.8756137490272522
# Attempted to log scalar metric val_map:
# 0.7259299484520537
# Attempted to log scalar metric val_map_at_1:
# 0.6072013093289689
# Attempted to log scalar metric val_gap:
# 0.29401833317665305
# Attempted to log scalar metric val_gap_at_1:
# 0.7074460911114795
# Attempted to log scalar metric val_micro-ap:
# 0.29401833317665305
# Evaluating holdout-logit
# Eval holdout-logit: 745 images from 745 total images
# 100% 32/32 [00:11<00:00,  2.73it/s]
# query_img_paths 745 nunique 745 ../../ePillID_data/classification_data/fcn_mix_weight/dc_224/1010.jpg
# query_labels 745 nunique 192
# Evaluation will be performed in 626 simulated 2-side pairs from 630 consumer images of 145 labels.
# query_outputs.shape torch.Size([745, 4902])
# Calculate distance matrix between all the labels 4902 and consumer-queries 626
# torch.Size([626, 4902])
# torch.Size([626])
# torch.Size([626])
# torch.Size([626, 4902])
# torch.Size([626])
# torch.Size([626])
# all_avg_precision (626, 7) (626, 4902) (626, 4902) 4902 626
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_ranking.py:677: RuntimeWarning: invalid value encountered in true_divide
#   recall = tps / tps[-1]
# torch.Size([626, 4902])
# torch.Size([626])
# torch.Size([626])
# torch.Size([626, 4902])
# torch.Size([626])
# torch.Size([626])
# all_avg_precision (626, 7) (626, 4902) (626, 4902) 4902 626
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_ranking.py:677: RuntimeWarning: invalid value encountered in true_divide
#   recall = tps / tps[-1]
# all_avg_precision (1252, 7) (1252, 4902) (1252, 4902) 4902 1252
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_ranking.py:677: RuntimeWarning: invalid value encountered in true_divide
#   recall = tps / tps[-1]
# qry_lbl_sim_matrix.shape torch.Size([626, 4902])
# Avg. time elapsed per metric query 0m 0s
# qry_lbl_sim_matrix torch.Size([626, 4902])
# torch.Size([626, 4902])
# torch.Size([626])
# torch.Size([626])
# torch.Size([626, 4902])
# torch.Size([626])
# torch.Size([626])
# Evaluation complete in 0m 34s
# all_avg_precision (626, 7) (626, 4902) (626, 4902) 4902 626
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_ranking.py:677: RuntimeWarning: invalid value encountered in true_divide
#   recall = tps / tps[-1]
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_ranking.py:677: RuntimeWarning: invalid value encountered in true_divide
#   recall = tps / tps[-1]
# Attempted to log image metric holdout-logit_11:07:43_PR-curve:
# <module 'matplotlib.pyplot' from '/usr/local/lib/python3.6/dist-packages/matplotlib/pyplot.py'>
# Attempted to log scalar metric holdout-logit_raw-top1-acc:
# 0.0
# Attempted to log scalar metric holdout-logit_raw-top5-acc:
# 0.0
# Attempted to log scalar metric holdout-logit_f_top1-acc:
# 0.0
# Attempted to log scalar metric holdout-logit_f_top5-acc:
# 0.0
# Attempted to log scalar metric holdout-logit_f_map:
# 0.0021902022036048973
# Attempted to log scalar metric holdout-logit_f_map_at_1:
# 0.0
# Attempted to log scalar metric holdout-logit_f_gap:
# 0.00029412145540964256
# Attempted to log scalar metric holdout-logit_f_gap_at_1:
# nan
# Attempted to log scalar metric holdout-logit_f_micro-ap:
# 0.00029412145540964256
# Attempted to log scalar metric holdout-logit_b_top1-acc:
# 0.0
# Attempted to log scalar metric holdout-logit_b_top5-acc:
# 0.0
# Attempted to log scalar metric holdout-logit_b_map:
# 0.0022567145330392945
# Attempted to log scalar metric holdout-logit_b_map_at_1:
# 0.0
# Attempted to log scalar metric holdout-logit_b_gap:
# 0.0002936019589902961
# Attempted to log scalar metric holdout-logit_b_gap_at_1:
# nan
# Attempted to log scalar metric holdout-logit_b_micro-ap:
# 0.0002936019589902961
# Attempted to log scalar metric holdout-logit_s_map:
# 0.002223458368322096
# Attempted to log scalar metric holdout-logit_s_map_at_1:
# 0.0
# Attempted to log scalar metric holdout-logit_s_gap:
# 0.0002925258613456077
# Attempted to log scalar metric holdout-logit_s_gap_at_1:
# nan
# Attempted to log scalar metric holdout-logit_s_micro-ap:
# 0.0002925258613456077
# Attempted to log scalar metric holdout-logit_top1-acc:
# 0.0
# Attempted to log scalar metric holdout-logit_top5-acc:
# 0.0
# Attempted to log scalar metric holdout-logit_map:
# 0.0023165816681888418
# Attempted to log scalar metric holdout-logit_map_at_1:
# 0.0
# Attempted to log scalar metric holdout-logit_gap:
# 0.0002994241933345158
# Attempted to log scalar metric holdout-logit_gap_at_1:
# nan
# Attempted to log scalar metric holdout-logit_micro-ap:
# 0.0002994241933345158
# Evaluating holdout
# Eval holdout: 745 images from 745 total images
# 100% 32/32 [00:11<00:00,  2.77it/s]
# query_img_paths 745 nunique 745 ../../ePillID_data/classification_data/fcn_mix_weight/dc_224/1010.jpg
# query_labels 745 nunique 192
# 100% 409/409 [02:31<00:00,  2.70it/s]
# Completed the eval model function. query:torch.Size([745, 2048]), ref:torch.Size([9804, 2048])
# Creating Torch cosine sim provider for metric evaluator
# Found 4902 classes in the references
# Evaluation will be performed in 626 simulated 2-side pairs from 630 consumer images of 145 labels.
# Calculate distance matrix between all the labels 4902 and consumer-queries 626
# torch.Size([626, 4902])
# torch.Size([626])
# torch.Size([626])
# torch.Size([626, 4902])
# torch.Size([626])
# torch.Size([626])
# all_avg_precision (626, 7) (626, 4902) (626, 4902) 4902 626
# torch.Size([626, 4902])
# torch.Size([626])
# torch.Size([626])
# torch.Size([626, 4902])
# torch.Size([626])
# torch.Size([626])
# all_avg_precision (626, 7) (626, 4902) (626, 4902) 4902 626
# all_avg_precision (1252, 7) (1252, 4902) (1252, 4902) 4902 1252
# Avg. time elapsed per metric query 0m 0s
# qry_lbl_sim_matrix torch.Size([626, 4902])
# torch.Size([626, 4902])
# torch.Size([626])
# torch.Size([626])
# torch.Size([626, 4902])
# torch.Size([626])
# torch.Size([626])
# Evaluation complete in 3m 5s
# {'f_top1-acc': 0.32108625769615173, 'f_top5-acc': 0.7044728398323059, 'f_map': 0.4858046749224538, 'f_map_at_1': 0.3210862619808307, 'f_gap': 0.11160219176728114, 'f_gap_at_1': 0.3800656182108245, 'f_micro-ap': 0.11160219176728114, 'f_PR-curve': <module 'matplotlib.pyplot' from '/usr/local/lib/python3.6/dist-packages/matplotlib/pyplot.py'>, 'b_top1-acc': 0.3482428193092346, 'b_top5-acc': 0.6757188439369202, 'b_map': 0.49554494084137163, 'b_map_at_1': 0.34824281150159747, 'b_gap': 0.10315381146142404, 'b_gap_at_1': 0.35874156153775516, 'b_micro-ap': 0.10315381146142404, 'b_PR-curve': <module 'matplotlib.pyplot' from '/usr/local/lib/python3.6/dist-packages/matplotlib/pyplot.py'>, 's_map': 0.4906748078819127, 's_map_at_1': 0.33466453674121405, 's_gap': 0.10655505355145217, 's_gap_at_1': 0.36627639843727844, 's_micro-ap': 0.10655505355145217, 's_PR-curve': <module 'matplotlib.pyplot' from '/usr/local/lib/python3.6/dist-packages/matplotlib/pyplot.py'>, 'top1-acc': 0.6006389856338501, 'top5-acc': 0.8993610143661499}
# all_avg_precision (626, 7) (626, 4902) (626, 4902) 4902 626
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_ranking.py:677: RuntimeWarning: invalid value encountered in true_divide
#   recall = tps / tps[-1]
# Attempted to log image metric holdout_11:10:55_PR-curve:
# <module 'matplotlib.pyplot' from '/usr/local/lib/python3.6/dist-packages/matplotlib/pyplot.py'>
# Attempted to log scalar metric holdout_f_top1-acc:
# 0.32108625769615173
# Attempted to log scalar metric holdout_f_top5-acc:
# 0.7044728398323059
# Attempted to log scalar metric holdout_f_map:
# 0.4858046749224538
# Attempted to log scalar metric holdout_f_map_at_1:
# 0.3210862619808307
# Attempted to log scalar metric holdout_f_gap:
# 0.11160219176728114
# Attempted to log scalar metric holdout_f_gap_at_1:
# 0.3800656182108245
# Attempted to log scalar metric holdout_f_micro-ap:
# 0.11160219176728114
# Attempted to log scalar metric holdout_b_top1-acc:
# 0.3482428193092346
# Attempted to log scalar metric holdout_b_top5-acc:
# 0.6757188439369202
# Attempted to log scalar metric holdout_b_map:
# 0.49554494084137163
# Attempted to log scalar metric holdout_b_map_at_1:
# 0.34824281150159747
# Attempted to log scalar metric holdout_b_gap:
# 0.10315381146142404
# Attempted to log scalar metric holdout_b_gap_at_1:
# 0.35874156153775516
# Attempted to log scalar metric holdout_b_micro-ap:
# 0.10315381146142404
# Attempted to log scalar metric holdout_s_map:
# 0.4906748078819127
# Attempted to log scalar metric holdout_s_map_at_1:
# 0.33466453674121405
# Attempted to log scalar metric holdout_s_gap:
# 0.10655505355145217
# Attempted to log scalar metric holdout_s_gap_at_1:
# 0.36627639843727844
# Attempted to log scalar metric holdout_s_micro-ap:
# 0.10655505355145217
# Attempted to log scalar metric holdout_top1-acc:
# 0.6006389856338501
# Attempted to log scalar metric holdout_top5-acc:
# 0.8993610143661499
# Attempted to log scalar metric holdout_map:
# 0.7323913819773646
# Attempted to log scalar metric holdout_map_at_1:
# 0.6006389776357828
# Attempted to log scalar metric holdout_gap:
# 0.28388663046072643
# Attempted to log scalar metric holdout_gap_at_1:
# 0.6827520578674207
# Attempted to log scalar metric holdout_micro-ap:
# 0.28388663046072643
# saving predictions ../../ePillID_data/classification_results/lr0.0001_dr0.0_lrpatience2_lrfactor0.5_resnet18_202007121035
# saving predictions outputs

# %%
# Check predictions
# !ls outputs
# Out:
# eval_predictions_pilltypeid_nih_sidelbls0.01_metric_5folds_3.csv

# %% [markdown]
# ## Next steps
#
# * Try train_cv.py for cross-validation
# * Try different models e.g. resnet50 and BCNN
# * Increase max_epochs (need 200-300 epochs to converge)
